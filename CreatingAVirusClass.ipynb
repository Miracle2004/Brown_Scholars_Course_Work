# %% [markdown]
# # Creating a Virus Class

# %% [markdown]
# We briefly touched on a number of viruses, some can be mild and some are vastly deadly. However, all viruses have similar base traits that allows us to classify it as a virus, different from bacteria.
#
# List some variables and values that can be classified as a common trait among viruses:

# %%
virusDefinition = "submicroscopic pathogen that targets living cells"
virusGoal = "reproduce using the cells of the host"
virusLocation = "genetic information is located in the capsid"

# %% [markdown]
# What is a **class**?
# * Classes provide a means of bundling data and functionality together.
# * Creating a new class creates a new type of object (a user-defined variable), allowing new instances of that type to be made.
#
# Create a `Virus` class with all of the above properties.

# %%
class Virus:
  definition = "submicroscopic pathogen that targets living cells"
  goal = "reproduce using the cells of the host"
  location = "genetic information is located in the capsid"
#Class variables are variable defined in the class. sotring information that is specific to the class

# %% [markdown]
# Now create an OBJECT/instance of class "Virus".

# %%
virus_specimen = Virus()

# %% [markdown]
# Access the class variables of the virus specimen using the dot operator.

# %%
virus_specimen.definition
# Out:
# 'submicroscopic pathogen that targets living cells'

# %%
virus_specimen.goal
# Out:
# 'reproduce using the cells of the host'

# %%
virus_specimen.location
# Out:
# 'genetic information is located in the capsid'

# %% [markdown]
# ## Inheritance

# %% [markdown]
# **Inheritance** allows us to define a class that inherits all the methods and properties from another class.
#
# Inheritance involves two types of classes:
# * Parent Class (the class being inherited from, also called base class)
# * Child Class (the class that inherits from another class, also called derived class)
#
# In the context of viruses, what is the parent class? What are possible child classes?
#
# **List of viruses:**
# * COVID-19
# * HIV
# * HSV-1
# * Ebola
# * Zika
#
# What are some traits of these specific viruses that can vary?
#
# Create a child class using the specific traits for `MEV1` from the movie, *Contagion* (2011), and inherit the attributes from the `Virus` class.

# %%
class MEV1(Virus): #the parenthesis is for inheriting from the Virus class
  genus = "Henipavirus"
  family = "Paramyxoviridae"
  transmission = ["physical contact", "food/drink", "fomites", "respiratory droplets"]
  symptoms = ["high fever", "encephalitis", "seizures", "coughing","sweating", "troubled breathing"]
  host = ["humans", "pigs", "bats"]

# %% [markdown]
# Create an object representing a specimen of MEV-1 using the class we just created.

# %%
mev1Specimen = MEV1()

# %% [markdown]
# Access the class variables specific to `MEV1` and also its inherited traits from its parent, `Virus`.

# %%
mev1Specimen.definition
# Out:
# 'submicroscopic pathogen that targets living cells'

# %%
mev1Specimen.genus
# Out:
# 'Henipavirus'

# %%
mev1Specimen.host
# Out:
# ['humans', 'pigs', 'bats']

# %%
print(mev1Specimen.location, mev1Specimen.symptoms)
# Out:
# genetic information is located in the capsid ['high fever', 'encephalitis', 'seizures', 'coughing', 'sweating', 'troubled breathing']

# %% [markdown]
# ## Activity - Create Child Classes for each Virus!

# %% [markdown]
# Using the concept of classes and inheritance of the `Virus` class, create a separate child class for each of the following viruses:
#
# * COVID-19
# * HIV
# * HSV-1
# * Ebola
# * Zika
#
#
# Make sure to include the following attributes for each type of virus:
# * genus
# * family
# * host
# * transmission
# * symptoms
# * any other attribute you would like to add which pertains to that specific virus! :D
#
# Don't forget to access the attributes, afterward.
#
# You may use these resources when researching the traits of each virus.
# * https://viralzone.expasy.org/678
# * Google

# %%
class COVID19(Virus):
  genus = "Betacoronavirus"
  family = "Coronaviridae"
  host = ["birds","humans", "other mammals"]
  transmission = ["respiratory droplets", "aerosol spread", "fomites", "zoonosis"]
  symptoms = ["fever", "cough", "shortness of breath", "fatigue", "loss of taste or smell"]

covid19Specimen = COVID19()

# %%
print(covid19Specimen.family + "             " + covid19Specimen.location)
# Out:
# Coronaviridae             genetic information is located in the capsid

# %%
class HIV(Virus):
  genus = "Lenitvirus"
  family = "Retroviridae"
  host = "Human"
  transmission = ["blood", "sexual contact"]
  symptoms = ["fever", "chills", "sore throat", "fatigue"]
  disease = "AIDS"

HIVspecimen = HIV()

# %%
print(str(HIVspecimen.transmission) + "            " + HIVspecimen.goal)
# Out:
# ['blood', 'sexual contact']            reproduce using the cells of the host

# %%
class HSV1(Virus):
  genus = "Simplexvirus"
  family = "Herpesviridae"
  host = "human"
  trnasmission = ["sexual contact", "saliva"]
  symptoms = ["itching", "fever", "headache", "problems urinating"]
  
  
HSV1specimen = HSV1()
print(HSV1specimen.genus + "          " + HSV1specimen.definition)
# Out:
# Simplexvirus          submicroscopic pathogen that targets living cells

# %%
class ebola(Virus):
  genus = "Ebolavirus"
  family = "Filoviridae"
  transmission = ["physical contact", "zoonosis"]
  symptoms = ["high fever", "fatigue", "headache", "muscle/joint pain", "vomiting"]
  host = ["human", "monkey", "bats"]

# %%
class Zika(Virus):
  genus = "Flavivirus"
  family = "Flaviridae"
  transmission = ["zoonosis", "anthropod site"]
  symptoms = ["fever", "joint pain", "rash"]
  host = ["human", "monkeys", "mosquitoes"]
  R0 = 2.055
  yearDiscovered = 1947

Zikaspecimen = Zika()
print(str(Zikaspecimen.transmission) + "         "+ str(Zikaspecimen.host) + "             " + str(Zikaspecimen.yearDiscovered))
# Out:
# ['zoonosis', 'anthropod site']         ['human', 'monkeys', 'mosquitoes']             1947
