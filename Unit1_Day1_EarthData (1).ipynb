# %% [markdown]
# # Analyzing our Planet Earth data
#
# Let's use Python to input and analyze the data we collected in the Hall of Planet Earth.
#
# **Reminder: To run the code in a Jupyter Notebook cell, click inside the cell and press "shift" and "return" on your keyboard at the same time.**

# %% [markdown]
# ## Working with numerical earth science data

# %% [markdown]
# Assign the percent of each ore that contains the mineral to each variable below:

# %%
# Note: You do not need to include the % sign. 
chromium = 25
vanadium = 2
platinum = 0.0008

# %% [markdown]
# Now print out each of these variables:

# %%
print(chromium)
print(vanadium)
print(platinum)
# Out:
# 25
# 2
# 0.0008

# %% [markdown]
# Next, assign the percent of vanadium ore that **does not** contain the mineral to a new variable and then print it out:

# %%
emptyOre = (100 - vanadium)
print(emptyOre)# Hint: You will need to use subtraction
# Out:
# 98

# %% [markdown]
# Now convert the value you calculated above into a decimal and print the result:

# %%
print(emptyOre / 100)# Hint: You will need to use division
# Out:
# 0.98

# %% [markdown]
# Can you identify which of the values you worked with above are integers and which are floats?

# %% [markdown]
# ## Working with textual earth science data

# %% [markdown]
# Assign the name of each type of lava to a variable below:

# %%
lavatype_1 = " pahoehoe"
lavatype_2 = " aa" # Hint: Remember that strings need to be in quotes!

# %% [markdown]
# Now print out each of these variables:

# %%
print(lavatype_1 + lavatype_2)
# Out:
#  pahoehoe aa

# %% [markdown]
# You can add strings together to make one long print statement, even if some of those strings are stored in variables.
#
# Assign your favorite object from the Hall of Planet Earth as a string to the object variable below and then run the cell below to see how it works:

# %%
name = "petrified tree "
print("The " + name + "is one of the exhibited objects that helps us learn about planet Earth!")
# Out:
# The petrified tree is one of the exhibited objects that helps us learn about planet Earth!

# %% [markdown]
# Now try printing out a sentence that tells the reader what the two types of lava are:

# %%
print("The two types of lava are" + lavatype_1 + " and" + lavatype_2 + ".")
# Out:
# The two types of lava are pahoehoe and aa.

# %% [markdown]
# ## Mixing different types of earth science data

# %% [markdown]
# Create a variable for each piece of data related to the deformed rocks from Wingdale, NY and decide whether the value should be a string, a float, or an integer:
# - Where the rock was found
# - Type of rock
# - Rock age
# - Temperature at which the rock formed
# - Depth at which the rock formed

# %%
location = "Wingdale, NY"
rock_type = "schists"
rock_age = 440000000
formation_temp = 550
formation_depth = 8 #I did not have the data for this

# %% [markdown]
# Print out a sentence that explains where the rocks were found and what kind of rock they are:

# %%
print("The rocks are found " + location + " and are " + rock_type + ".")
# Out:
# The rocks are found Wingdale, NY and are schists.

# %% [markdown]
# Print out the difference between the deformed rock's temperature at formation and the boiling point of water (100 degrees Celsius):

# %%
print(formation_temp - 100)
# Out:
# 450

# %% [markdown]
# Create two new variables that contain the age and length of the San Andreas Fault:

# %%
faultAge = 30000000
faultDepth = 1200

# %% [markdown]
# Print out the difference in age between the deformed rocks and the San Andreas Fault:

# %%
print(rock_age-faultAge)
# Out:
# 410000000

# %% [markdown]
# How much longer is the San Andreas Fault than the depth of the deformed rock's formation? Print out the difference:

# %%
print(faultDepth-formation_depth)
# Out:
# 1192

# %% [markdown]
# ## Bonus Challenge 1
# If you finish everything above, try this bonus challenge
#
# Create three new variables with information from your data collection sheet and experiment with adding, subtracting, and printing these variables:

# %%
averageMovement=5
faultAge = 30000000
faultDepth = 1200
distanceMoved=300
year=365
total=distanceMoved/faultAge*year
print(total)

# Hint: Think about which data types can be added together
# Out:
# 0.0036500000000000005

# %% [markdown]
# ## Bonus Challenge 2
# If you finish everything above, try this bonus challenge
#
# Run the code below to learn about the type() function:

# %%
var1 = 5
var2 = "Rocks rock"
var3 = 3.2

#The type() function tells you the data type of a value
print(type(var1))
print(type(var2))
print(type(var3))
# Out:
# <class 'int'>
# <class 'str'>
# <class 'float'>

# %% [markdown]
# Now try it yourself! print out the type of some variables you've created above:

# %%
print(type (rock_type))
print(type (rock_age))
print(type (location))
print( type (formation_temp))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'str'>
# <class 'int'>

# %% [markdown]
# You can also change the type of some values stored in variables using the following functions:
# - str() turns a value into a string
# - int() turns a value into an integer
# - float() turns a value into a float
#
# Run the code below to learn more:

# %%
varA = "1"
varB = 1.0
varC = 1

print(int(varA))
print(str(varB))
print(float(varC))
# Out:
# 1
# 1.0
# 1.0

# %% [markdown]
# Not all values can be turned into all types. Try running the code below:

# %%
print(int("Rocks rock!"))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-70-aaa7ec378d36> in <module>()
# ----> 1 print(int("Rocks rock!"))
#
# ValueError: invalid literal for int() with base 10: 'Rocks rock!'

# %% [markdown]
# Now try it yourself! Create your own variables and try changing their types:

# %%
print(str (42.0))
print(int (-.277777777))
print(float (7679321))
print(str (45/8 + -.4444444 ))
print(int (2/3))
print(float (10/10))
print(int (22/7))
print(float (22/7))
# Out:
# 42.0
# 0
# 7679321.0
# 5.1805556
# 0
# 1.0
# 3
# 3.142857142857143
